# %% [markdown]
#                 1.CRIANDO BANCO DE DADOS

# %%
import sqlite3
#criar um banco de dados e não o salvar, ele ficar salvo na memoria temporaria
#banco = sqlite3.connect(":memory")

#crio um obj que vai conectr o banco de dados co esse nome
banco = sqlite3.connect("teste.db")
#conectar o banco quando estiver desconectado

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Criar um cursor (é como um indentificador de arquivo) para poder usar comando SQL
cursor = banco.cursor()
#iniciar o cursor dps de conectar o banco

# %% [markdown]
#             Criando e preenchendo uma tabela

# %%
#criar a tabale estudante, com os campos nome idade email departament0
cursor.execute("CREATE TABLE estudantes (id_estudante integer, nome_estudante text, idade integer, email text, id_departamento integer)")

#Inserir dados na tabela        dentro dos valores usa '' para não confundir o programa
#cursor.execute("INSERT INTO estudantes VALUES(1, 'Maria', 40, 'mariadosanjos@mentorama.com', 2)")

banco.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-12-151cca5eb8fb> in <module>
#       1 #criar a tabale estudante, com os campos nome idade email departament0
# ----> 2 cursor.execute("CREATE TABLE estudantes (id_estudante integer, nome_estudante text, idade integer, email text, id_departamento integer)")
#       3
#       4 #Inserir dados na tabela        dentro dos valores usa '' para não confundir o programa
#       5 #cursor.execute("INSERT INTO estudantes VALUES(1, 'Maria', 40, 'mariadosanjos@mentorama.com', 2)")
#
# OperationalError: table estudantes already exists

# %% [markdown]
#                 Consultando dados

# %%
#consultar dados da tabela estudante
cursor.execute("SELECT * FROM estudantes")
print(cursor.fetchall())
# Out:
# [(1, 'Maria', 40, 'mariadosanjos@mentorama.com', 2)]

# %% [markdown]
#             2.Manipulando dados com SQLite
#
# ![image.png](attachment:image.png)

# %%
#usar "iner join" dps bixão caralho lek iner joy, porra, mas o bagulho n gasta muito processamento, é gasta sim, e é bem abstrato cara, doidera, vamo la fera, VAMO DALE.

lista_de_estudantes = [('2' , 'Felipe'   , '18', 'felipe@mentorama.com'   , '1'),
                       ('3' , 'Maria'    , '45', 'maria@mentorama.com'    , '4'),
                       ('4' , 'João'     , '33', 'joao@mentorama.com'     , '4'),
                       ('5' , 'Lucia'    , '17', 'lucia@mentorama.com'    , '2'),
                       ('6' , 'Pedro'    , '32', 'pedro@mentorama.com'    , 'NULL'),
                       ('7' , 'Izabela'  , '23', 'izabela@mentorama.com'  , '3'),
                       ('8' , 'Eduardo'  , '59', 'eduardo@mentorama.com'  , '4'),
                       ('9' , 'Tiago'    , '38', 'tiago@mentorama.com'    , '5'),
                       ('10', 'Ana'      , '25', 'ana@mentorama.com'      , 'NULL'),
                       ('11', 'Carol'    , '36', 'carol@mentorama.com'    , '2'),
                       ('12', 'Leonardo' , '28', 'leonardo@mentorama.com' , '3'),
                       ('13', 'Vanessa'  , '45', 'vanessa@mentorama.com'  , '4'),
                       ('14', 'João'     , '43', 'joao@mentorama.com'     , '5'),
                       ('15', 'Mari'     , '25', 'mari@mentorama.com'     , '6')
                      ]

# %%
#5? referentes aos 5 campos de inseção das lista estudante
cursor.executemany("""INSERT INTO estudantes VALUES (?,?,?,?,?)""", lista_de_estudantes)
print("Confirmação do bloco")
banco.commit()
# Out:
# Confirmação do bloco

# %%
#consulta dados da tabela "estudante"
cursor.execute("SELECT * FROM estudantes")
print(cursor.fetchall())
# Out:
# [(1, 'Maria', 40, 'mariadosanjos@mentorama.com', 2), (2, 'Felipe', 18, 'felipe@mentorama.com', 1), (3, 'Maria', 45, 'maria@mentorama.com', 4), (4, 'João', 33, 'joao@mentorama.com', 4), (5, 'Lucia', 17, 'lucia@mentorama.com', 2), (6, 'Pedro', 32, 'pedro@mentorama.com', 'NULL'), (7, 'Izabela', 23, 'izabela@mentorama.com', 3), (8, 'Eduardo', 59, 'eduardo@mentorama.com', 4), (9, 'Tiago', 38, 'tiago@mentorama.com', 5), (10, 'Ana', 25, 'ana@mentorama.com', 'NULL'), (11, 'Carol', 36, 'carol@mentorama.com', 2), (12, 'Leonardo', 28, 'leonardo@mentorama.com', 3), (13, 'Vanessa', 45, 'vanessa@mentorama.com', 4), (14, 'João', 43, 'joao@mentorama.com', 5), (15, 'Mari', 25, 'mari@mentorama.com', 6)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Criamos o comando sql e depois executamos com o sursor
#essa variavel que recebera o comando
sql = """ 
UPDATE estudantes 
SET nome_estudante = 'Diego'
WHERE nome_estudante = 'Felipe'
"""

cursor.execute(sql)
banco.commit()
print("Registros atualizados com sucesso!")
# Out:
# Registros atualizados com sucesso!

# %%
#verificar se os dados foram atualidados msm

cursor.execute("SELECT * FROM estudantes")
print(cursor.fetchall())
#deu serto no entanto o nome esta como diego e o email esta como felipe, por isso vamos reverter
# Out:
# [(1, 'Maria', 40, 'mariadosanjos@mentorama.com', 2), (2, 'Diego', 18, 'felipe@mentorama.com', 1), (3, 'Maria', 45, 'maria@mentorama.com', 4), (4, 'João', 33, 'joao@mentorama.com', 4), (5, 'Lucia', 17, 'lucia@mentorama.com', 2), (6, 'Pedro', 32, 'pedro@mentorama.com', 'NULL'), (7, 'Izabela', 23, 'izabela@mentorama.com', 3), (8, 'Eduardo', 59, 'eduardo@mentorama.com', 4), (9, 'Tiago', 38, 'tiago@mentorama.com', 5), (10, 'Ana', 25, 'ana@mentorama.com', 'NULL'), (11, 'Carol', 36, 'carol@mentorama.com', 2), (12, 'Leonardo', 28, 'leonardo@mentorama.com', 3), (13, 'Vanessa', 45, 'vanessa@mentorama.com', 4), (14, 'João', 43, 'joao@mentorama.com', 5), (15, 'Mari', 25, 'mari@mentorama.com', 6)]

# %%
#reverter a mudança de nomes 
sql = """ 
UPDATE estudantes 
SET nome_estudante = 'Felipe'
WHERE nome_estudante = 'Diego'
"""

cursor.execute(sql)
banco.commit()
print("Reverção feita com sucesso!")
# Out:
# Reverção feita com sucesso!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#sql = """
#DELETE FROM estudantes
#WHERE nome_estudante = 'Maria'
#"""

cursor.execute(sql)
banco.commit()
print("Comando não quebro, é isso ai cara")
# http://pythonclub.com.br/gerenciando-banco-dados-sqlite3-python-parte2.html
# http://support.zendesk.com/hc//pt-br/articles/203691016-Formata%C3%A7%C3%A3o-de-texto-com-Markdown#topic
# Out:
# [('Maria',), ('Felipe',), ('Maria',), ('João',), ('Lucia',), ('Pedro',), ('Izabela',), ('Eduardo',), ('Tiago',), ('Ana',), ('Carol',), ('Leonardo',), ('Vanessa',), ('João',), ('Mari',)]

# %%
#consultando o delete
cursor.execute("SELECT * FROM estudantes")
print(cursor.fetchall())
# Out:
# [(2, 'Felipe', 18, 'felipe@mentorama.com', 1), (4, 'João', 33, 'joao@mentorama.com', 4), (5, 'Lucia', 17, 'lucia@mentorama.com', 2), (6, 'Pedro', 32, 'pedro@mentorama.com', 'NULL'), (7, 'Izabela', 23, 'izabela@mentorama.com', 3), (8, 'Eduardo', 59, 'eduardo@mentorama.com', 4), (9, 'Tiago', 38, 'tiago@mentorama.com', 5), (10, 'Ana', 25, 'ana@mentorama.com', 'NULL'), (11, 'Carol', 36, 'carol@mentorama.com', 2), (12, 'Leonardo', 28, 'leonardo@mentorama.com', 3), (13, 'Vanessa', 45, 'vanessa@mentorama.com', 4), (14, 'João', 43, 'joao@mentorama.com', 5), (15, 'Mari', 25, 'mari@mentorama.com', 6)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#sql = """
#DROP TABLE estudantes
#"""

cursor.execute(sql)
banco.commit()
print("Deletou bixão")
# Out:
# Deletou bixão

# %%
#consultando o drop
cursor.execute("SELECT * FROM estudantes")
print(cursor.fetchall())
#tem q dar erro mesmo pois a tabela foi deletada e não sera encontrada"
#DALE#
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-18-8b266e6129b5> in <module>
#       1 #consultando o drop
# ----> 2 cursor.execute("SELECT * FROM estudantes")
#       3 print(cursor.fetchall())
#
# OperationalError: no such table: estudantes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Seleciona dados da tabela estudante onde a especificamos um "parametro" para indicar quais dados selecionar
cursor.execute("""SELECT * FROM estudantes
                WHERE idade = '33' """)
print(cursor.fetchall())
# Out:
# [(4, 'João', 33, 'joao@mentorama.com', 4)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Seleciona dados da tabela estudante onde o nome e a idade são especificados 
cursor.execute("""SELECT * FROM estudantes 
                WHERE nome_estudante = 'Felipe' AND idade = '18' """)
print(cursor.fetchall())
# Out:
# [(2, 'Felipe', 18, 'felipe@mentorama.com', 1)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#uma ou outra condição deve ser sadizfeita para executar o resto do codigo, se ambas forem sadisteitas de forma não simutanea( ou seja a idade é sadisfeita mas o nome não, posteriormente a idade não é sadisfeita mas o ome é) o codigo sera execudato tbm, neste caso pesquisando com parametro referente a qual condição foi sadisfeita
cursor.execute("""SELECT * FROM estudantes 
                WHERE nome_estudante = 'Maria' OR idade = '18' """)
print(cursor.fetchall())
# Out:
# [(1, 'Maria', 40, 'mariadosanjos@mentorama.com', 2), (2, 'Felipe', 18, 'felipe@mentorama.com', 1), (3, 'Maria', 45, 'maria@mentorama.com', 4)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cursor.execute("""SELECT * FROM estudantes 
                WHERE NOT nome_estudante = 'Maria' OR idade = '18' """)
print(cursor.fetchall())
# Out:
# [(2, 'Felipe', 18, 'felipe@mentorama.com', 1), (4, 'João', 33, 'joao@mentorama.com', 4), (5, 'Lucia', 17, 'lucia@mentorama.com', 2), (6, 'Pedro', 32, 'pedro@mentorama.com', 'NULL'), (7, 'Izabela', 23, 'izabela@mentorama.com', 3), (8, 'Eduardo', 59, 'eduardo@mentorama.com', 4), (9, 'Tiago', 38, 'tiago@mentorama.com', 5), (10, 'Ana', 25, 'ana@mentorama.com', 'NULL'), (11, 'Carol', 36, 'carol@mentorama.com', 2), (12, 'Leonardo', 28, 'leonardo@mentorama.com', 3), (13, 'Vanessa', 45, 'vanessa@mentorama.com', 4), (14, 'João', 43, 'joao@mentorama.com', 5), (15, 'Mari', 25, 'mari@mentorama.com', 6)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cursor.execute("""SELECT * FROM estudantes
               WHERE NOT nome_estudante = 'Maria' AND idade > '18' """)
print(cursor.fetchall())
# Out:
# [(4, 'João', 33, 'joao@mentorama.com', 4), (6, 'Pedro', 32, 'pedro@mentorama.com', 'NULL'), (7, 'Izabela', 23, 'izabela@mentorama.com', 3), (8, 'Eduardo', 59, 'eduardo@mentorama.com', 4), (9, 'Tiago', 38, 'tiago@mentorama.com', 5), (10, 'Ana', 25, 'ana@mentorama.com', 'NULL'), (11, 'Carol', 36, 'carol@mentorama.com', 2), (12, 'Leonardo', 28, 'leonardo@mentorama.com', 3), (13, 'Vanessa', 45, 'vanessa@mentorama.com', 4), (14, 'João', 43, 'joao@mentorama.com', 5), (15, 'Mari', 25, 'mari@mentorama.com', 6)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cursor.execute("""SELECT nome_estudante, idade FROM estudantes
                ORDER BY idade ASC""")
print(cursor.fetchall())
# Out:
# [('Lucia', 17), ('Felipe', 18), ('Izabela', 23), ('Ana', 25), ('Mari', 25), ('Leonardo', 28), ('Pedro', 32), ('João', 33), ('Carol', 36), ('Tiago', 38), ('Maria', 40), ('João', 43), ('Maria', 45), ('Vanessa', 45), ('Eduardo', 59)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cursor.execute("SELECT nome_estudante, id_departamento FROM estudantes GROUP BY nome_estudante")
print(cursor.fetchall())
# Out:
# [('Ana', 'NULL'), ('Carol', 2), ('Eduardo', 4), ('Felipe', 1), ('Izabela', 3), ('João', 4), ('Leonardo', 3), ('Lucia', 2), ('Mari', 6), ('Maria', 2), ('Pedro', 'NULL'), ('Tiago', 5), ('Vanessa', 4)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sql = """
SELECT COUNT(nome_estudante)
FROM estudantes
WHERE nome_estudante = "Maria"
"""

cursor.execute(sql)
print(cursor.fetchall())
# Out:
# [(2,)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sql = """
SELECT AVG(idade)
FROM estudantes
WHERE idade > '18'
"""

cursor.execute(sql)
print(cursor.fetchall())
# Out:
# [(36.30769230769231,)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sql = """
SELECT SUM(idade)
FROM estudantes
WHERE idade > '18'
"""

cursor.execute(sql)
print(cursor.fetchall())
# Out:
# [(472,)]

# %%
# Criar tabela departamentos, com id_departamento, nome_departamento
cursor.execute("""CREATE TABLE departamentos (id_departamento integer PRIMARY KEY, nome_departamento text )""")
print("Tabela criada")
# Out:
# Tabela criada

# %%
#Inserir dados atraves da lista de tuplas
lista_departamento = [('1','TI'),
                      ('2','Fisica'),
                      ('3','Matemática'),
                      ('4','Engenharia'),
                      ('5','Biologia'),
                      ('6','Historia')]

cursor.executemany("""INSERT INTO departamentos VALUES (?,?)""", lista_departamento)
print("Dados inseridos com sucesso!")
banco.commit()
# Out:
# Dados inseridos com sucesso!

# %%
#Delete tabela departamento, se precisar 
#cursor.execute("""DROP TABLE departamentos""")
#print(cursor.fetchall())
# Out:
# []

# %%
#consultar dados
cursor.execute("""SELECT * FROM departamentos""")
cursor.fetchall()
# Out:
# [(1, 'TI'),
#  (2, 'Fisica'),
#  (3, 'Matemática'),
#  (4, 'Engenharia'),
#  (5, 'Biologia'),
#  (6, 'Historia')]

# %% [markdown]
# JOIN diagrams! Let’s look at CROSS JOIN first, because all other JOIN types can be derived from CROSS JOIN:
#
# ![image-4.png](attachment:image-4.png)
#
# Lembre-se, em uma junção cruzada (em SQL também escrita com uma lista de tabelas separada por vírgulas, historicamente) é apenas pegar cada item do lado esquerdo e combiná-lo com cada item do lado direito. Quando você CROSS JOIN uma tabela de 3 linhas com uma tabela de 4 linhas, você obterá 3 × 4 = 12 linhas de resultado. Veja, estou usando um caractere “x” para escrever a multiplicação. Ou seja, através".
#
# ![image-2.png](attachment:image-2.png)
#
# Em texto simples, um INNER JOIN é um CROSS JOIN em que apenas as combinações que preenchem um determinado predicado são retidas. Por exemplo
#
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)

# %%
sql = """SELECT
    estudantes.nome_estudante,
    departamentos.nome_departamento
FROM departamentos
INNER JOIN estudantes ON estudantes.id_departamento = departamentos.id_departamento """
#ou
#INNER JOIN estudantes USING(id_departamento)"""
cursor.execute(sql)
cursor.fetchall()
# Out:
# [('Maria', 'Fisica'),
#  ('Felipe', 'TI'),
#  ('Maria', 'Engenharia'),
#  ('João', 'Engenharia'),
#  ('Lucia', 'Fisica'),
#  ('Izabela', 'Matemática'),
#  ('Eduardo', 'Engenharia'),
#  ('Tiago', 'Biologia'),
#  ('Carol', 'Fisica'),
#  ('Leonardo', 'Matemática'),
#  ('Vanessa', 'Engenharia'),
#  ('João', 'Biologia'),
#  ('Mari', 'Historia')]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sql = """SELECT
    estudantes.nome_estudante,
    departamentos.nome_departamento
    FROM estudantes 
    LEFT JOIN departamentos USING (id_departamento)"""
#ou
#LEFT OUTER JOIN departamentos ON estudantes.id_departamento = departamentos.id_departamento""" 
#LEFT JOIN

cursor.execute(sql)
cursor.fetchall()
# Out:
# [('Maria', 'Fisica'),
#  ('Felipe', 'TI'),
#  ('Maria', 'Engenharia'),
#  ('João', 'Engenharia'),
#  ('Lucia', 'Fisica'),
#  ('Pedro', None),
#  ('Izabela', 'Matemática'),
#  ('Eduardo', 'Engenharia'),
#  ('Tiago', 'Biologia'),
#  ('Ana', None),
#  ('Carol', 'Fisica'),
#  ('Leonardo', 'Matemática'),
#  ('Vanessa', 'Engenharia'),
#  ('João', 'Biologia'),
#  ('Mari', 'Historia')]

# %% [markdown]
# ![image.png](attachment:image.png)
# PRODUTO CARTESIANO de ~@# é #$%@  é POSIBILIDADES/COMBINAÇÕES (vulgo multiplicação heheh)

# %%
sql = """SELECT
    estudantes.nome_estudante,
    departamentos.nome_departamento
    FROM estudantes 
    CROSS JOIN departamentos """

cursor.execute(sql)
cursor.fetchall()
# Out:
# [('Maria', 'TI'),
#  ('Maria', 'Fisica'),
#  ('Maria', 'Matemática'),
#  ('Maria', 'Engenharia'),
#  ('Maria', 'Biologia'),
#  ('Maria', 'Historia'),
#  ('Felipe', 'TI'),
#  ('Felipe', 'Fisica'),
#  ('Felipe', 'Matemática'),
#  ('Felipe', 'Engenharia'),
#  ('Felipe', 'Biologia'),
#  ('Felipe', 'Historia'),
#  ('Maria', 'TI'),
#  ('Maria', 'Fisica'),
#  ('Maria', 'Matemática'),
#  ('Maria', 'Engenharia'),
#  ('Maria', 'Biologia'),
#  ('Maria', 'Historia'),
#  ('João', 'TI'),
#  ('João', 'Fisica'),
#  ('João', 'Matemática'),
#  ('João', 'Engenharia'),
#  ('João', 'Biologia'),
#  ('João', 'Historia'),
#  ('Lucia', 'TI'),
#  ('Lucia', 'Fisica'),
#  ('Lucia', 'Matemática'),
#  ('Lucia', 'Engenharia'),
#  ('Lucia', 'Biologia'),
#  ('Lucia', 'Historia'),
#  ('Pedro', 'TI'),
#  ('Pedro', 'Fisica'),
#  ('Pedro', 'Matemática'),
#  ('Pedro', 'Engenharia'),
#  ('Pedro', 'Biologia'),
#  ('Pedro', 'Historia'),
#  ('Izabela', 'TI'),
#  ('Izabela', 'Fisica'),
#  ('Izabela', 'Matemática'),
# ...
